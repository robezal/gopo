# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from os import path
import re

# %%
main_page = requests.get('https://www.poemhunter.com/poems/sonnets/')
second_page = requests.get('https://www.poemhunter.com/poems/sonnets/page-2/')

# %%
pages = []
pages.append(BeautifulSoup(main_page.text, 'lxml'))
pages.append(BeautifulSoup(second_page.text, 'lxml'))

# %%
cp = re.compile(".*cursor:pointer")

# %%
temp = []
titles = []
authors = []
links = []
for page in pages:
    for tag in page.find_all('li', style=cp):
        temp = tag.get_text().split('\n')
        titles.append(temp[2])
        authors.append(temp[4].strip('\t').strip('\r'))
        lst = str(tag).split("'")
        links.append(lst[1])
print(len(titles))
print(titles)
print(len(authors))
print(authors)
print(len(links))
print(links)
# Out:
# 100
# ...

# %%
def get_poem(link):
    db = re.compile("display:block.*")
    poem_link = 'https://www.poemhunter.com/' + link
    poetry = requests.get(poem_link)
    bsp = BeautifulSoup(poetry.text, 'lxml')
    html_poem = bsp.find('p', style=db)
    return str(html_poem)

# %%
poems = []
for pLink in links:
    poem = get_poem(pLink)
    poem = poem.replace('<br/>','\n')
    poem = poem.replace('<i>', '')
    poem = poem.replace('</i>', '')
    poem = poem.replace('</p>', '')
    poem = poem.split('\n',1)[1]
    poem = poem.strip()
    poem = poem.replace('\n.\n', '\n')
    poems.append(poem)
len(poems)
# Out:
# 100

# %%
for poem in poems:
    print(poem)
    print('-'*45)
# Out:
# O Winter! frozen pulse and heart of fire,
# What loss is theirs who from thy kingdom turn
# Dismayed, and think thy snow a sculptured urn
# Of death! Far sooner in midsummer tire
# The streams than under ice. June could not hire
# Her roses to forego the strength they learn
# In sleeping on thy breast. No fires can burn
# The bridges thou dost lay where men desire
# In vain to build.
# O Heart, when Love's sun goes
# To northward, and the sounds of singing cease,
# Keep warm by inner fires, and rest in peace.
# Sleep on content, as sleeps the patient rose.
# Walk boldly on the white untrodden snows,
# The winter is the winter's own release.
# ---------------------------------------------
# The month of carnival of all the year,
# When Nature lets the wild earth go its way,
# And spend whole seasons on a single day.
# The spring-time holds her white and purple dear;
# October, lavish, flaunts them far and near;
# The summer charily her reds doth lay
# ...

# %%
df = pd.DataFrame({'Author':authors, 'Title':titles, 'Poem':poems, 'Form':'Sonnet'})
df.head()
# Out:
#                     Author                            Title  \
# 0       Helen Hunt Jackson   A Calendar Of Sonnets: January
# 1       Helen Hunt Jackson   A Calendar Of Sonnets: October
# 2  Edna St. Vincent Millay            [four Sonnets (1922)]
# 3       Helen Hunt Jackson     A Calendar Of Sonnets: April
# 4       Helen Hunt Jackson  A Calendar Of Sonnets: November
#
#                                                 Poem    Form
# 0  O Winter! frozen pulse and heart of fire, \nWh...  Sonnet
# 1  The month of carnival of all the year, \nWhen ...  Sonnet
# 2  I1.\n   Love, though for this you riddle me wi...  Sonnet
# 3  No days such honored days as these! While yet ...  Sonnet
# 4  This is the treacherous month when autumn days...  Sonnet

# %%
df.to_csv('Sonnets2_100.csv')

# %%
df.Author.value_counts()
# Out:
# William Shakespeare                24
# Edna St. Vincent Millay            16
# Helen Hunt Jackson                 12
# Wilfrid Scawen Blunt               11
# Rainer Maria Rilke                  8
# Dante Gabriel Rossetti              7
# Algernon Charles Swinburne          6
# Elizabeth Barrett Browning          5
# Christina Georgina Rossetti         2
# Delmore Schwartz                    1
# Francis Thompson                    1
# Michael Drayton                     1
# Charles Hamilton Sorley             1
# George William Lewis Marshal ..     1
# Edwin Arlington Robinson            1
# John Donne                          1
# Susan Williams                      1
# John Keats                          1
# Name: Author, dtype: int64

# %%
df[df.Author == 'John Keats']
# Out:
#         Author                Title  \
# 41  John Keats  Two Sonnets On Fame
#
#                                                  Poem    Form
# 41  I.\nFame, like a wayward girl, will still be c...  Sonnet
