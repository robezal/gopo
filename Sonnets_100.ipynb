# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from os import path
import re

# %%
main_page = requests.get('https://www.poemhunter.com/poems/sonnet/')
second_page = requests.get('https://www.poemhunter.com/poems/sonnet/page-2/')

# %%
pages = []
pages.append(BeautifulSoup(main_page.text, 'lxml'))
pages.append(BeautifulSoup(second_page.text, 'lxml'))

# %%
cp = re.compile(".*cursor:pointer")

# %%
temp = []
titles = []
authors = []
links = []
for page in pages:
    for tag in page.find_all('li', style=cp):
        temp = tag.get_text().split('\n')
        titles.append(temp[2])
        authors.append(temp[4].strip('\t').strip('\r'))
        lst = str(tag).split("'")
        links.append(lst[1])
print(len(titles))
print(titles)
print(len(authors))
print(authors)
print(len(links))
print(links)
# Out:
# 100
# ...

# %%
def get_poem(link):
    db = re.compile("display:block.*")
    poem_link = 'https://www.poemhunter.com/' + link
    poetry = requests.get(poem_link)
    bsp = BeautifulSoup(poetry.text, 'lxml')
    html_poem = bsp.find('p', style=db)
    return str(html_poem)

# %%
poems = []
for pLink in links:
    poem = get_poem(pLink)
    poem = poem.replace('<br/>','\n')
    poem = poem.replace('<i>', '')
    poem = poem.replace('</i>', '')
    poem = poem.replace('</p>', '')
    poem = poem.split('\n',1)[1]
    poem= poem.strip()
    poems.append(poem)
len(poems)
# Out:
# 100

# %%
for poem in poems:
    print(poem)
    print('-'*45)
# Out:
# And now you're mine. Rest with your dream in my dream.
# Love and pain and work should all sleep, now.
# The night turns on its invisible wheels,
# and you are pure beside me as a sleeping amber.
#
# No one else, Love, will sleep in my dreams. You will go,
# we will go together, over the waters of time.
# No one else will travel through the shadows with me,
# only you, evergreen, ever sun, ever moon.
#
# Your hands have already opened their delicate fists
# and let their soft drifting signs drop away; your eyes closed like two gray
# wings, and I move
#
# after, following the folding water you carry, that carries
# me away. The night, the world, the wind spin out their destiny.
# Without you, I am your dream, only that, and that is all.
# ---------------------------------------------
# Bright star, would I were steadfast as thou art! -
# Not in lone splendour hung aloft the night,
# And watching, with eternal lids apart,
# Like Nature's patient sleepless Eremite,
# ...

# %%
df = pd.DataFrame({'Author':authors, 'Title':titles, 'Poem':poems, 'Form':'Sonnet'})
df.head()
# Out:
#             Author            Title  \
# 0     Pablo Neruda     Sonnet Lxxxi
# 1       John Keats  His Last Sonnet
# 2     Pablo Neruda        Sonnet Xi
# 3     Pablo Neruda      Sonnet Viii
# 4  Edgar Allan Poe  Sonnet- Silence
#
#                                                 Poem    Form
# 0  And now you're mine. Rest with your dream in m...  Sonnet
# 1  Bright star, would I were steadfast as thou ar...  Sonnet
# 2  I crave your mouth, your voice, your hair.\nSi...  Sonnet
# 3  If your eyes were not the color of the moon,\n...  Sonnet
# 4  There are some qualities- some incorporate thi...  Sonnet

# %%
df.to_csv('Sonnets_100.csv')

# %%
df2 = pd.read_csv('Sonnets_100.csv')

# %%
df2.Author.value_counts()
# Out:
# William Shakespeare            32
# John Donne                     21
# Elizabeth Barrett Browning     18
# Oscar Wilde                     3
# Pablo Neruda                    3
# Edgar Allan Poe                 3
# Edmund Spenser                  2
# John Milton                     2
# Rupert Brooke                   2
# John Keats                      2
# Tamara Beryl Latham             1
# Elizabeth Bishop                1
# George Barker                   1
# William Wordsworth              1
# Thomas Gray                     1
# Samuel Taylor Coleridge         1
# Christina Georgina Rossetti     1
# William Allingham               1
# Dante Gabriel Rossetti          1
# Sir John Suckling               1
# Federico García Lorca           1
# George Santayana                1
# Name: Author, dtype: int64

# %%
df2[df2.Author == 'John Keats']
# Out:
#     Unnamed: 0      Author                                       Title  \
# 1            1  John Keats                             His Last Sonnet
# 54          54  John Keats  To Haydon With A Sonnet Written On Seein..
#
#                                                  Poem    Form
# 1   Bright star, would I were steadfast as thou ar...  Sonnet
# 54  Haydon! forgive me that I cannot speak\nDefini...  Sonnet
