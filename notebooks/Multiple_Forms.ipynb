# %%
import pandas as pd

# %%
df14 = pd.read_csv('Shakespeare_Sonnets.csv', index_col = 0)
df15 = pd.read_csv('E_Browning_Sonnets.csv', index_col = 0)
df16 = pd.read_csv('ps_data_non_shakespeare_sonnets.csv')
df14.head()
# Out:
#                 Author Title  \
# 0  William Shakespeare     I
# 1  William Shakespeare    II
# 2  William Shakespeare   III
# 3  William Shakespeare    IV
# 4  William Shakespeare     V
#
#                                                 Poem    Form          Era  \
# 0  From fairest creatures we desire increase,\r\n...  Sonnet  Renaissance
# 1  When forty winters shall besiege thy brow,\r\n...  Sonnet  Renaissance
# 2  Look in thy glass and tell the face thou viewe...  Sonnet  Renaissance
# 3  Unthrifty loveliness, why dost thou spend\r\n ...  Sonnet  Renaissance
# 4  Those hours, that with gentle work did frame\r...  Sonnet  Renaissance
#
#    Type
# 0  Love
# 1  Love
# 2  Love
# 3  Love
# 4  Love

# %%
df15.head()
# Out:
#                        Author Title  \
# 0  Elizabeth Barrett Browning     I
# 1  Elizabeth Barrett Browning    II
# 2  Elizabeth Barrett Browning   III
# 3  Elizabeth Barrett Browning    IV
# 4  Elizabeth Barrett Browning     V
#
#                                                 Poem    Form        Era  Type
# 0  I thought once how Theocritus had sung\r\nOf t...  Sonnet  Victorian  Love
# 1  But only three in all God’s universe\r\nHave h...  Sonnet  Victorian  Love
# 2  Unlike are we, unlike, O princely Heart!\r\nUn...  Sonnet  Victorian  Love
# 3  Thou hast thy calling to some palace-floor,\r\...  Sonnet  Victorian  Love
# 4  I lift my heavy heart up solemnly,\r\nAs once ...  Sonnet  Victorian  Love

# %%
df16.head()
# Out:
#               author                                            content  \
# 0          EN JONSON  I that have been a lover, and could show it,\r...
# 1         JOHN DONNE  Thou hast made me, and shall thy work decay?\r...
# 2         JOHN DONNE  Show me dear Christ, thy spouse so bright and ...
# 3         JOHN DONNE  Since she whom I lov'd hath paid her last debt...
# 4  RICHARD BARNFIELD  Long have I longd to see my love againe,\r\nSt...
#
#                                            poem name          age  \
# 0    A Sonnet to the Noble Lady, the Lady Mary Wroth  Renaissance
# 1  Holy Sonnets: Thou hast made me, and shall thy...  Renaissance
# 2  Holy Sonnets: Show me dear Christ, thy spouse ...  Renaissance
# 3  Holy Sonnets: Since she whom I lov'd hath paid...  Renaissance
# 4                                          Sonnet 16  Renaissance
#
#                    type    form
# 0                  Love  Sonnet
# 1                Nature  Sonnet
# 2                  Love  Sonnet
# 3                  Love  Sonnet
# 4  Mythology & Folklore  Sonnet

# %%
df4 = df14[['Author', 'Poem', 'Form']].copy()
df5 = df15[['Author', 'Poem', 'Form']].copy()
df6 = df16[['author', 'content', 'form']].copy()
df6.columns = ['Author', 'Poem', 'Form']

# %%
df5.head()
# Out:
#                        Author  \
# 0  Elizabeth Barrett Browning
# 1  Elizabeth Barrett Browning
# 2  Elizabeth Barrett Browning
# 3  Elizabeth Barrett Browning
# 4  Elizabeth Barrett Browning
#
#                                                 Poem    Form
# 0  I thought once how Theocritus had sung\r\nOf t...  Sonnet
# 1  But only three in all God’s universe\r\nHave h...  Sonnet
# 2  Unlike are we, unlike, O princely Heart!\r\nUn...  Sonnet
# 3  Thou hast thy calling to some palace-floor,\r\...  Sonnet
# 4  I lift my heavy heart up solemnly,\r\nAs once ...  Sonnet

# %%
df17 = pd.read_csv('Tibullus_Williams_Elegies.csv', index_col = 0)
df7 = df17[['Author','Content','Form']]
df7.columns = ['Author', 'Poem', 'Form']
df7.tail()
# Out:
#       Author                                               Poem   Form
# 20  Tibullus  Be kinder, gods! Let not the dreams come true\...  Elegy
# 21  Tibullus  You take your pleasure by Etrurian streams,\r\...  Elegy
# 22  Tibullus  Come radiant Bacchus! With the hallowed leaf\r...  Elegy
# 23  Tibullus  No! ne'er shall rival lure me from thine arms!...  Elegy
# 24      Ovid  If tears for their dead sons, in deep despair,...  Elegy

# %%
df18a = pd.read_csv('Haiku.txt', names = ['Poem', 'Author'])
df18b = df18a[['Author','Poem']]
df18 = pd.DataFrame({'Author':df18b.Author, 'Poem':df18b.Poem, 'Form':'Haiku'})
df18
# Out:
#                Author                                               Poem  \
# 0    - Kobayahsi Issa           The wren\nEarns his living\nNoiselessly.
# 1      - Matsuo Bashō  From time to time\nThe clouds give rest\nTo th...
# 2        - Yosa Buson   Over-ripe sushi,\nThe Master\nIs full of regret.
# 3    - Masaoaka Shiki  Consider me\nAs one who loved poetry\nAnd pers...
# 4      - Matsuo Bashō  In the cicada's cry\nNo sign can foretell\nHow...
# ..                ...                                                ...
# 79     -Christina Sng  drifting snowflakes\nthe police car’s ascent\n...
# 80     -Roland Packer  evening breeze\nthrough the barnboards\nfinal bid
# 81  -Robyn Hood Black  wedding invitations\nthe press and release\nof...
# 82     -Julie Warther  paddling through stars\nthe wake of a boat\nlo...
# 83  -Olivier Schopfer  pride parade\nfrom behind a cloud\nthe sun com...
#
#      Form
# 0   Haiku
# 1   Haiku
# 2   Haiku
# 3   Haiku
# 4   Haiku
# ..    ...
# 79  Haiku
# 80  Haiku
# 81  Haiku
# 82  Haiku
# 83  Haiku
#
# [84 rows x 3 columns]

# %%
writer = []
df8 = df18.copy()
for name in df8['Author']:
    if name != float:
#         print(name.strip(' ').strip('-').strip(' '))
        writer.append(name.strip(' ').strip('-').strip(' '))
df8.Author = writer.copy()
df8.to_csv('Haiku.csv')
df8.head()
# Out:
#            Author                                               Poem   Form
# 0  Kobayahsi Issa           The wren\nEarns his living\nNoiselessly.  Haiku
# 1    Matsuo Bashō  From time to time\nThe clouds give rest\nTo th...  Haiku
# 2      Yosa Buson   Over-ripe sushi,\nThe Master\nIs full of regret.  Haiku
# 3  Masaoaka Shiki  Consider me\nAs one who loved poetry\nAnd pers...  Haiku
# 4    Matsuo Bashō  In the cicada's cry\nNo sign can foretell\nHow...  Haiku

# %%
df19 = pd.read_csv('Elegies_100_edit.csv', index_col = 0)
df9 = df19[['Author', 'Poem', 'Form']].copy()
df9.head()
# Out:
#                Author                                               Poem  \
# 0         Thomas Gray  The Curfew tolls the knell of parting day,\nTh...
# 1        Dylan Thomas  Too proud to die; broken and blind he died\nTh...
# 2  Rainer Maria Rilke  Who, if I cried out, would hear me among the a...
# 3    Theodore Roethke  (My student, thrown by a horse)\n\nI remember ...
# 4        Wilfred Owen  Hush, thrush! Hush, missen-thrush, I listen......
#
#     Form
# 0  Elegy
# 1  Elegy
# 2  Elegy
# 3  Elegy
# 4  Elegy

# %%
df13 = pd.read_csv('Ballads_100_edit.csv', index_col = 0)
df3 = df13[['Author', 'Poem', 'Form']].copy()
df3.head()
# Out:
#                   Author                                               Poem  \
# 0        Edgar Allan Poe  The ring is on my hand,\n         And the wrea...
# 1  Federico García Lorca  translated by Will Kirkland\n\nThe moon came i...
# 2       Gwendolyn Brooks  Oh mother, mother, where is happiness?\nThey t...
# 3            Oscar Wilde  (In memoriam\nC. T. W.\nSometime trooper of th...
# 4       Gwendolyn Brooks  Rudolph Reed was oaken.\nHis wife was oaken to...
#
#      Form
# 0  Ballad
# 1  Ballad
# 2  Ballad
# 3  Ballad
# 4  Ballad

# %%
df10 = pd.read_csv('Sonnets_100.csv', index_col = 0)
df0 = df10[['Author', 'Poem', 'Form']].copy()
df0.head()
# Out:
#             Author                                               Poem    Form
# 0     Pablo Neruda  And now you're mine. Rest with your dream in m...  Sonnet
# 1       John Keats  Bright star, would I were steadfast as thou ar...  Sonnet
# 2     Pablo Neruda  I crave your mouth, your voice, your hair.\nSi...  Sonnet
# 3     Pablo Neruda  If your eyes were not the color of the moon,\n...  Sonnet
# 4  Edgar Allan Poe  There are some qualities- some incorporate thi...  Sonnet

# %%
df0 = df0[df0.Author != 'William Shakespeare']
df0 = df0[df0.Author != 'Elizabeth Barrett Browning']
df0.head()
# Out:
#             Author                                               Poem    Form
# 0     Pablo Neruda  And now you're mine. Rest with your dream in m...  Sonnet
# 1       John Keats  Bright star, would I were steadfast as thou ar...  Sonnet
# 2     Pablo Neruda  I crave your mouth, your voice, your hair.\nSi...  Sonnet
# 3     Pablo Neruda  If your eyes were not the color of the moon,\n...  Sonnet
# 4  Edgar Allan Poe  There are some qualities- some incorporate thi...  Sonnet

# %%
df120 = pd.read_csv('Sonnets2_100.csv', index_col = 0)
df20 = df120[['Author', 'Poem', 'Form']].copy()
df20.head()
# Out:
#                     Author                                               Poem  \
# 0       Helen Hunt Jackson  O Winter! frozen pulse and heart of fire, \nWh...
# 1       Helen Hunt Jackson  The month of carnival of all the year, \nWhen ...
# 2  Edna St. Vincent Millay  I1.\n   Love, though for this you riddle me wi...
# 3       Helen Hunt Jackson  No days such honored days as these! While yet ...
# 4       Helen Hunt Jackson  This is the treacherous month when autumn days...
#
#      Form
# 0  Sonnet
# 1  Sonnet
# 2  Sonnet
# 3  Sonnet
# 4  Sonnet

# %%
df20 = df20[df20.Author != 'William Shakespeare']
df20 = df20[df20.Author != 'Elizabeth Barrett Browning']
df20 = df20[df20.Author != 'Susan Williams']

df20.head()
# Out:
#                     Author                                               Poem  \
# 0       Helen Hunt Jackson  O Winter! frozen pulse and heart of fire, \nWh...
# 1       Helen Hunt Jackson  The month of carnival of all the year, \nWhen ...
# 2  Edna St. Vincent Millay  I1.\n   Love, though for this you riddle me wi...
# 3       Helen Hunt Jackson  No days such honored days as these! While yet ...
# 4       Helen Hunt Jackson  This is the treacherous month when autumn days...
#
#      Form
# 0  Sonnet
# 1  Sonnet
# 2  Sonnet
# 3  Sonnet
# 4  Sonnet

# %%
df1 = df4.append(df5).append(df6).append(df7).append(df8).append(df9).append(df3).append(df0).append(df20)
df1
# Out:
#                   Author                                               Poem  \
# 0    William Shakespeare  From fairest creatures we desire increase,\r\n...
# 1    William Shakespeare  When forty winters shall besiege thy brow,\r\n...
# 2    William Shakespeare  Look in thy glass and tell the face thou viewe...
# 3    William Shakespeare  Unthrifty loveliness, why dost thou spend\r\n ...
# 4    William Shakespeare  Those hours, that with gentle work did frame\r...
# ..                   ...                                                ...
# 95  Wilfrid Scawen Blunt  Whate'er the cost to me, with this farewell,\n...
# 96  Wilfrid Scawen Blunt  If the past year were offered me again,\nWith ...
# 97  Wilfrid Scawen Blunt  Nay, dear one, ask me not to leave thee yet.\n...
# 98  Wilfrid Scawen Blunt  Where is the pride for which I once was blamed...
# 99  Wilfrid Scawen Blunt  I sue thee not for pity on my case.\nIf I have...
#
#       Form
# 0   Sonnet
# 1   Sonnet
# 2   Sonnet
# 3   Sonnet
# 4   Sonnet
# ..     ...
# 95  Sonnet
# 96  Sonnet
# 97  Sonnet
# 98  Sonnet
# 99  Sonnet
#
# [2707 rows x 3 columns]

# %%
df1.Form.unique()
# Out:
# array(['Sonnet', 'Elegy', 'Haiku', 'Ballad', nan], dtype=object)

# %%
df1.Author.unique()
# Out:
# array(['William Shakespeare', 'Elizabeth Barrett Browning', 'EN JONSON',
#        'JOHN DONNE', 'RICHARD BARNFIELD', 'SIR PHILIP SIDNEY',
#        'EDMUND SPENSER', 'Tibullus', 'Ovid', 'Kobayahsi Issa',
#        'Matsuo Bashō', 'Yosa Buson', 'Masaoaka Shiki', 'Kobayashi Issa',
#        'Masaoka Shiki', 'Kato Shuson', 'Natsume Soseki', 'Murakami Kijo',
#        'Roger Abe', 'Carol Steele', 'Alison Woolpert', 'Karina Young',
#        'Linda Papanicolaou', 'Dyana Basist', 'Mimi Ahern',
#        'Amy Ostenso-Kennedy', 'Phillip Kennedy', 'ra', 'cs', 'ky', 'lp',
#        'aw', 'db', 'aok', 'pk', 'ma', 'Raquel D. Bailey',
#        'Michael Morell', 'Michele L. Harvey', 'Paul Kulwatno',
#        'Jacquie Pearce', 'Martha Magenta', 'Temple Cone',
#        'Matthew Markworth', 'Roland Packer', 'Annette Makino',
#        'Joe McKeon', 'Brett Brady', 'Alan Summers', 'Ron C. Moss',
#        'Jayne Miller', 'Barry George', 'Sam Bateman', 'Gary Hotham',
#        'Michele Root-Bernstein', 'Tigz DePalma', 'Lew Watts',
#        'Corine Timmer', 'Celia Stuart-Powles', 'Francine Banwarth',
#        'Christina Sng', 'Robyn Hood Black', 'Julie Warther',
#        'Olivier Schopfer', 'Thomas Gray', 'Dylan Thomas',
#        'Rainer Maria Rilke', 'Theodore Roethke', 'Wilfred Owen',
#        'Alexander Pope', 'John Donne', 'Jonathan Swift',
#        'Lawrence Ferlinghetti', 'Anne Sexton', 'Oliver Goldsmith',
#        'Carolyn Forché', 'Anna Akhmatova', 'Gilbert Keith Chesterton',
#        'Edna St. Vincent Millay', 'Lorraine Margueritte Gasrel  ..',
#        'John Gay', 'Siegfried Sassoon', 'Sandra Fowler', 'Alan Dugan',
#        'Joseph Brodsky', 'James Thomson', 'Ambrose Bierce',
#        'Mark Akenside', 'Doren Robbins', 'Kenneth Slessor',
#        'Friedrich Schiller', 'Subbaraman N V', 'David Herbert Lawrence',
#        'Stephen Vincent Benet', 'Jean Valentine', 'Mary Darby Robinson',
#        'Charlotte Smith', 'Amelia Opie', 'Robert Burns',
#        'Samuel Taylor Coleridge', 'John Dryden', 'Ben Jonson',
#        'Percy Bysshe Shelley', 'George Gordon Byron',
#        'Theodora (Theo) Onken', 'Henry King',
#        'Vignesh Ravishankar Shanmugam', 'William Cowper',
#        'Thomas Parnell', 'James Hogg', 'Aleister Crowley',
#        'James Beattie', 'Leo Yankevich', 'Thomas Chatterton',
#        'William Shenstone', 'chandra thiagarajan', 'Muriel Rukeyser',
#        'Edgar Allan Poe', 'Federico García Lorca', 'Gwendolyn Brooks',
#        'Oscar Wilde', 'Algernon Charles Swinburne', 'Sara Teasdale',
#        'Langston Hughes', 'Geoffrey Chaucer', 'Allen Ginsberg',
#        'Walt Whitman', 'Rudyard Kipling', 'Sidney Lanier', 'Ezra Pound',
#        'Thomas Lovell Beddoes', 'Edwin Arlington Robinson',
#        'François Villon', 'William Butler Yeats', 'Francis Duggan',
#        'Banjo Paterson', 'Sir Walter Scott', 'Alfred Lord Tennyson',
#        'Robert Graves', 'Yevgeny Yevtushenko', nan, ' as field to fen',
#        ' with harp on shoulder', ' went home.', " the sentries' tramp",
#        ' and drove him flying', ' but lean and pale:',
#        ' with his harp and rags', ' such as lags', " with a woman's eyes",
#        ' when that she had glared a span', ' bowing heavily',
#        ' ""O great heart in the night', ' and rise after the morn',
#        ' the yawning trees', ' yet laughs among the swords',
#        ' and is at rest?', ' with a great beard curled', ' labouring',
#        ' like this woman here', ' a nameless star', ' it may go ill',
#        ' a doubtful star', ' as it is in heaven.',
#        ' the woman caught a cake', ' outlandish garments',
#        ' though of antique worth', ' with rank hair like yellow grass',
#        ' Gorlias', ' come from his first mass', ' a Dane.',
#        ' ""by my sword;', ' then', ' brothers', ' fires and cords',
#        ' ten by ten', ' a thing downtrod', ' even God', ' and pouring',
#        ' and knew', ' and the forest fled', ' far',
#        ' though not in hardihood;', ' crimson-clad',
#        ' if you have any prayers', ' drunkards in my cellar',
#        ' and after', ' like rat in rafter', ' ""And when did Britain',
#        ' he said', ' King of England', ' deployed and stood;', ' coarse',
#        ' giving tongue', ' where', ' but lightly',
#        ' truly we be broken hearts', ' it is said', ' and bent it on',
#        ' whose doom grew dark; and shone', ' as in pain',
#        ' put hand to head', ' must give all things. Verily',
#        ' prince of England', ' like a cup', ' ""Do thou take my sword',
#        ' our Lord', ' with a random eye', ' and the seventh',
#        ' and swayed--', ' as falls a battle-tower', ' rushing earthward',
#        ' ""Fallen is the tower of Wessex', ' cried Marcus',
#        ' Wulf and Gorlias', ' and I make you free!',
#        ' Hildred hard in English land', ' stand Gorlias', ' Halfgar',
#        ' hold up on knee!', ' Gurth', ' now!""', ' as with bloody spear',
#        ' in his mid-career.', ' ""God hath broken the evil spear',
#        ' earth and wood', ' scutum', ' who turned his blow',
#        ' the man from Italy', ' leaping up alive',
#        ' as when a juggler flings', ' yea', ' like a cliff.',
#        ' I count it fit', ' by Thor', ' a drunkard smoke', ' blind',
#        ' the last alarms', ' green edge for ever', ' alone',
#        ' from the land.', ' and hunger and aspire', ' wise or wild',
#        ' but not in scorn:', ' very small', ' alone.', ' said Alfred',
#        ' a thousand strong', ' great war remains:',
#        ' when he rode out commonly', ' the riding sign',
#        ' the hunting sign', ' all at large', ' by rule and rod',
#        ' and what he saw', ' a roaring ring', ' halloing',
#        ' the barrels spill', ' banners rend', ' how knock their knees',
#        ' or stricken pale', ' his men came murderously',
#        ' drinking death.', ' torn;', ' but more bold',
#        ' and crooked swords', ' without name',
#        ' above candles all aflame', ' Charlemagne.',
#        ' seeing such embassies', ' from tide to tide--', ' meteors',
#        ' being full.', ' Lord King', ' and ill', ' guard',
#        ' the King grows old', ' and return no more.\' ""',
#        ' and return no more?', ' charger and spear', ' the Downs',
#        ' fell beyond fell', ' sad and slow', ' and I know',
#        ' covering the chalk.', ' this shall be the sign of them',
#        ' say the scribes', ' and loud', ' while all men slept',
#        ' velvet foot', " like a great green witch's wheel", 'Ballad',
#        'John Davidson', 'Franklin Pierce Adams',
#        'Johann Wolfgang von Goethe', 'Henry Lawson', 'Sir Henry Newbolt',
#        'Robert Southey', 'Zbigniew Herbert', 'Ellis Parker Butler',
#        'Dante Gabriel Rossetti', 'Eugene Field', 'Michael Drayton',
#        'Ankoku Gekido', 'Paul Laurence Dunbar', 'Emily Pauline Johnson',
#        'Padraic Colum', 'koyel mitra', 'Delmore Schwartz',
#        'Thomas Babbington Macaulay', 'Marie E J Pitt', 'James Joyce',
#        'Robert William Service', 'Bjørnstjerne Bjørnson', 'John Skelton',
#        'William Makepeace Thackeray', 'Pablo Neruda', 'John Keats',
#        'John Milton', 'Sir John Suckling', 'Rupert Brooke',
#        'Elizabeth Bishop', 'Christina Georgina Rossetti', 'George Barker',
#        'Tamara Beryl Latham', 'William Wordsworth', 'George Santayana',
#        'Edmund Spenser', 'William Allingham', 'Helen Hunt Jackson',
#        'George William Lewis Marshal ..', 'Charles Hamilton Sorley',
#        'Francis Thompson', 'Wilfrid Scawen Blunt'], dtype=object)

# %%
df1.Form.value_counts()
# Out:
# Sonnet    348
# Elegy     125
# Ballad     99
# Haiku      84
# Name: Form, dtype: int64

# %%
df1.to_csv('Multiple_Forms.csv')
