# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from os import path
import re

# %%
main_page = requests.get('https://www.poemhunter.com/poems/ballad/')
second_page = requests.get('https://www.poemhunter.com/poems/ballad/page-2/')

# %%
pages = []
pages.append(BeautifulSoup(main_page.text, 'lxml'))
pages.append(BeautifulSoup(second_page.text, 'lxml'))

# %%
cp = re.compile(".*cursor:pointer")

# %%
temp = []
titles = []
authors = []
links = []
for page in pages:
    for tag in page.find_all('li', style=cp):
        temp = tag.get_text().split('\n')
        titles.append(temp[2])
        authors.append(temp[4].strip('\t').strip('\r'))
        lst = str(tag).split("'")
        links.append(lst[1])
print(len(titles))
print(titles)
print(len(authors))
print(authors)
print(len(links))
print(links)
# Out:
# 100
# ...

# %%
def get_poem(link):
    db = re.compile("display:block.*")
    poem_link = 'https://www.poemhunter.com/' + link
    poetry = requests.get(poem_link)
    bsp = BeautifulSoup(poetry.text, 'lxml')
    html_poem = bsp.find('p', style=db)
    return str(html_poem)

# %%
poems = []
for pLink in links:
    poem = get_poem(pLink)
    poem = poem.replace('<br/>','\n')
    poem = poem.replace('<i>', '')
    poem = poem.replace('</i>', '')
    poem = poem.replace('</p>', '')
    poem = poem.split('\n',1)[1]
    poem= poem.strip()
    poems.append(poem)
len(poems)
# Out:
# 100

# %%
for poem in poems:
    print(poem)
    print('-'*45)
# Out:
# The ring is on my hand,
#          And the wreath is on my brow;
#        Satin and jewels grand
#        Are all at my command,
#          And I am happy now.
#
#        And my lord he loves me well;
#          But, when first he breathed his vow,
#        I felt my bosom swell-
#        For the words rang as a knell,
#        And the voice seemed his who fell
#        In the battle down the dell,
#          And who is happy now.
#
#        But he spoke to re-assure me,
#          And he kissed my pallid brow,
#        While a reverie came o'er me,
#        And to the church-yard bore me,
#        And I sighed to him before me,
#        Thinking him dead D'Elormie,
#        "Oh, I am happy now!"
#
#        And thus the words were spoken,
#          And this the plighted vow,
#        And, though my faith be broken,
#        And, though my heart be broken,
#        Here is a ring, as token
#          That I am happy now!
#
#        Would God I could awaken!
# ...

# %%
df = pd.DataFrame({'Author':authors, 'Title':titles, 'Poem':poems, 'Form':'Ballad'})
df.head()
# Out:
#                   Author                       Title  \
# 0        Edgar Allan Poe               Bridal Ballad
# 1  Federico García Lorca          Ballad Of The Moon
# 2       Gwendolyn Brooks           The Sonnet-Ballad
# 3            Oscar Wilde  The Ballad Of Reading Gaol
# 4       Gwendolyn Brooks  The Ballad Of Rudolph Reed
#
#                                                 Poem    Form
# 0  The ring is on my hand,\n         And the wrea...  Ballad
# 1  translated by Will Kirkland\n\nThe moon came i...  Ballad
# 2  Oh mother, mother, where is happiness?\nThey t...  Ballad
# 3  (In memoriam\nC. T. W.\nSometime trooper of th...  Ballad
# 4  Rudolph Reed was oaken.\nHis wife was oaken to...  Ballad

# %%
df.to_csv('Ballads_100.csv')
